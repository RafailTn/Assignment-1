# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
filepath = "/Volumes/Mac/Users/rafailadam/Downloads/mlincompbio/Assignment-1/data/"
train_data = filepath + "assignment1_dev_set.csv"

# %%
train_dframe = pd.read_csv(train_data, header=0)
print(train_dframe.head())
print(train_dframe.describe()
# Out:
#    Unnamed: 0   Project ID Experiment type     Sex  Host age    BMI  \
# 0           0   PRJEB11419    Metagenomics    Male      53.0  19.01
# 1           1  PRJNA388263    Metagenomics  Female      21.0  23.50
# 2           2  PRJNA388263    Metagenomics    Male      52.0  25.80
# 3           3   PRJEB11419    Metagenomics  Female      40.0  23.49
# 4           4   PRJEB11419    Metagenomics  Female      30.0  22.60
#
#   Disease MESH ID  Acholeplasma axanthum  Acidaminococcus fermentans  \
# 0         D006262               0.000000                    0.000000
# 1         D006262               0.001028                    0.000000
# 2         D006262               0.001406                    0.000000
# 3         D006262               0.000000                    0.008825
# 4         D006262               0.002878                    0.037419
#
#    Acidaminococcus intestini  ...  Clostridium sphenoides  \
# 0                   0.000000  ...                0.005891
# 1                   0.000000  ...                0.000000
# 2                   0.000000  ...                0.000000
# 3                   0.273562  ...                0.017649
# 4                   7.359970  ...                0.305106
#
#    Clostridium spiroforme  Clostridium stercorarium  Clostridium symbiosum  \
# 0                0.029457                  0.000000               0.000000
# 1                0.002569                  0.412652               0.003083
# 2                0.005624                  0.002812               0.007031
# 3                0.198553                  0.000000               0.158842
# 4                0.135283                  0.000000               0.051811
#
#    Clostridium thermosuccinogenes  Clostridium xylanolyticum  \
# 0                        0.002946                   0.000000
# 1                        0.000000                   0.000000
# 2                        0.000000                   0.000000
# 3                        0.030886                   0.101483
# 4                        0.054689                   0.083473
#
#    Eubacterium brachy  Eubacterium dolichum  Eubacterium sulci  \
# 0            0.000000              0.000000           0.002946
# 1            0.008736              0.014903           0.077597
# 2            0.000000              0.000000           0.005624
# 3            0.000000              0.000000           0.000000
# 4            0.020148              0.000000           0.054689
#
#    Ruminococcus gnavus
# 0             0.100153
# 1             0.004625
# 2             0.016873
# 3             0.000000
# 4             0.011513
#
# [5 rows x 141 columns]
#        Unnamed: 0    Host age        BMI  Acholeplasma axanthum  \
# count  489.000000  489.000000  489.00000             489.000000
# mean   244.000000   46.703497   24.93955               0.016818
# std    141.306405   15.728231    4.20771               0.145035
# min      0.000000   19.000000   16.97000               0.000000
# 25%    122.000000   31.000000   22.38000               0.000000
# 50%    244.000000   52.000000   25.10000               0.000000
# 75%    366.000000   58.000000   25.80000               0.000000
# max    488.000000   81.000000   67.26000               2.861300
#
#        Acidaminococcus fermentans  Acidaminococcus intestini  \
# count                  489.000000                 489.000000
# mean                     0.029968                   0.294917
# std                      0.197816                   0.804704
# min                      0.000000                   0.000000
# 25%                      0.000000                   0.000000
# 50%                      0.000000                   0.001109
# 75%                      0.000000                   0.129398
# max                      2.622820                   7.660350
#
#        Actinomyces lingnae  Akkermansia muciniphila  Alistipes finegoldii  \
# count           489.000000               489.000000            489.000000
# mean              0.001608                 1.555914              0.249606
# std               0.010431                 4.306539              0.630670
# min               0.000000                 0.000000              0.000000
# 25%               0.000000                 0.003438              0.003380
# 50%               0.000000                 0.034284              0.044961
# 75%               0.000000                 0.820242              0.188550
# max               0.206426                38.834900              6.068670
#
#        Alistipes indistinctus  ...  Clostridium sphenoides  \
# count              489.000000  ...              489.000000
# mean                 0.061796  ...                0.029822
# std                  0.239054  ...                0.090605
# min                  0.000000  ...                0.000000
# 25%                  0.000000  ...                0.000000
# 50%                  0.000000  ...                0.000260
# 75%                  0.045111  ...                0.027723
# max                  4.478660  ...                1.465160
#
#        Clostridium spiroforme  Clostridium stercorarium  \
# count              489.000000                489.000000
# mean                 0.247603                  0.032148
# std                  0.490321                  0.180606
# min                  0.000000                  0.000000
# 25%                  0.002570                  0.000000
# 50%                  0.047224                  0.000000
# 75%                  0.303173                  0.005768
# max                  3.714530                  3.118150
#
#        Clostridium symbiosum  Clostridium thermosuccinogenes  \
# count             489.000000                      489.000000
# mean                0.097871                        0.052936
# std                 0.197044                        0.310313
# min                 0.000000                        0.000000
# 25%                 0.004881                        0.000000
# 50%                 0.029362                        0.000000
# 75%                 0.100294                        0.015439
# max                 1.801190                        4.726220
#
#        Clostridium xylanolyticum  Eubacterium brachy  Eubacterium dolichum  \
# count                 489.000000          489.000000            489.000000
# mean                    0.038531            0.006565              0.012565
# std                     0.122225            0.018357              0.097056
# min                     0.000000            0.000000              0.000000
# 25%                     0.000000            0.000000              0.000000
# 50%                     0.001687            0.000000              0.000000
# 75%                     0.018352            0.005693              0.000000
# max                     1.173380            0.273194              1.939150
#
#        Eubacterium sulci  Ruminococcus gnavus
# count         489.000000           489.000000
# mean            0.041855             0.091976
# std             0.181979             0.416085
# min             0.000000             0.000000
# 25%             0.000000             0.000000
# 50%             0.003266             0.007035
# 75%             0.020020             0.020978
# max             2.478070             6.752840
#
# [8 rows x 137 columns]

# %%
for col in train_dframe.columns:
    print(f"Column {col} has {train_dframe[col].isna().sum()} NA values")
# Out:
# Column Unnamed: 0 has 0 NA values
# Column Project ID has 0 NA values
# Column Experiment type has 0 NA values
# Column Sex has 0 NA values
# Column Host age has 0 NA values
# Column BMI has 0 NA values
# Column Disease MESH ID has 0 NA values
# Column Acholeplasma axanthum has 0 NA values
# Column Acidaminococcus fermentans has 0 NA values
# Column Acidaminococcus intestini has 0 NA values
# Column Actinomyces lingnae has 0 NA values
# Column Akkermansia muciniphila has 0 NA values
# Column Alistipes finegoldii has 0 NA values
# Column Alistipes indistinctus has 0 NA values
# Column Alistipes obesi has 0 NA values
# Column Alistipes onderdonkii has 0 NA values
# Column Alistipes putredinis has 0 NA values
# Column Alistipes shahii has 0 NA values
# Column Alistipes sp. RMA 9912 has 0 NA values
# Column Alistipes timonensis has 0 NA values
# Column Anaerofilum pentosovorans has 0 NA values
# Column Anaerofustis stercorihominis has 0 NA values
# Column Anaerostipes butyraticus has 0 NA values
# Column Anaerostipes caccae has 0 NA values
# Column Anaerotruncus colihominis has 0 NA values
# Column Bacillus megaterium has 0 NA values
# Column Bacillus nealsonii has 0 NA values
# Column Bacteroides eggerthii has 0 NA values
# Column Bacteroides fragilis has 0 NA values
# Column Bacteroides gallinarum has 0 NA values
# Column Bacteroides graminisolvens has 0 NA values
# Column Bacteroides intestinalis has 0 NA values
# Column Bacteroides massiliensis has 0 NA values
# Column Bacteroides ovatus has 0 NA values
# Column Bacteroides plebeius has 0 NA values
# Column Bacteroides salyersiae has 0 NA values
# Column Barnesiella viscericola has 0 NA values
# Column Bifidobacterium bifidum has 0 NA values
# Column Bifidobacterium pseudocatenulatum has 0 NA values
# Column Bifidobacterium saguini has 0 NA values
# Column Bifidobacterium tsurumiense has 0 NA values
# Column Bilophila wadsworthia has 0 NA values
# Column Blautia coccoides has 0 NA values
# Column Blautia glucerasea has 0 NA values
# Column Blautia hydrogenotrophica has 0 NA values
# Column Blautia producta has 0 NA values
# Column Blautia schinkii has 0 NA values
# Column Butyricimonas virosa has 0 NA values
# Column Catabacter hongkongensis has 0 NA values
# Column Christensenella minuta has 0 NA values
# Column Clostridium amylolyticum has 0 NA values
# Column Clostridium malenominatum has 0 NA values
# Column Clostridium maximum has 0 NA values
# Column Clostridium sp. has 0 NA values
# Column Collinsella aerofaciens has 0 NA values
# Column Collinsella intestinalis has 0 NA values
# Column Collinsella tanakaei has 0 NA values
# Column Coprobacillus cateniformis has 0 NA values
# Column Coprococcus catus has 0 NA values
# Column Coprococcus eutactus has 0 NA values
# Column Desulfonispora thiosulfatigenes has 0 NA values
# Column Desulfosporosinus orientis has 0 NA values
# Column Desulfovibrio desulfuricans has 0 NA values
# Column Desulfovibrio fairfieldensis has 0 NA values
# Column Desulfovibrio piger has 0 NA values
# Column Desulfovibrio vulgaris has 0 NA values
# Column Ethanoligenens harbinense has 0 NA values
# Column Eubacterium desmolans has 0 NA values
# Column Eubacterium xylanophilum has 0 NA values
# Column Faecalibacterium sp. MC_41 has 0 NA values
# Column Flavonifractor plautii has 0 NA values
# Column Fusobacterium nucleatum has 0 NA values
# Column Holdemanella biformis has 0 NA values
# Column Holdemania filiformis has 0 NA values
# Column Hungatella hathewayi has 0 NA values
# Column Lachnospiraceae bacterium 3_1_57FAA_CT1 has 0 NA values
# Column Lachnospiraceae bacterium 5_1_63FAA has 0 NA values
# Column Lachnospiraceae bacterium 7_1_58FAA has 0 NA values
# Column Lactococcus lactis has 0 NA values
# Column Odoribacter splanchnicus has 0 NA values
# Column Oscillibacter valericigenes has 0 NA values
# Column Oxalobacter formigenes has 0 NA values
# Column Papillibacter cinnamivorans has 0 NA values
# Column Parabacteroides distasonis has 0 NA values
# Column Parabacteroides goldsteinii has 0 NA values
# Column Parabacteroides johnsonii has 0 NA values
# Column Parabacteroides merdae has 0 NA values
# Column Parasutterella excrementihominis has 0 NA values
# Column Peptoniphilus lacrimalis has 0 NA values
# Column Porphyromonas catoniae has 0 NA values
# Column Prevotella bivia has 0 NA values
# Column Prevotella buccalis has 0 NA values
# Column Prevotella oris has 0 NA values
# Column Prevotella oryzae has 0 NA values
# Column Prevotella paludivivens has 0 NA values
# Column Prevotella ruminicola has 0 NA values
# Column Prevotella shahii has 0 NA values
# Column Prevotella timonensis has 0 NA values
# Column Pseudobacteroides cellulosolvens has 0 NA values
# Column Pseudoflavonifractor capillosus has 0 NA values
# Column Roseburia hominis has 0 NA values
# Column Roseburia intestinalis has 0 NA values
# Column Ruminiclostridium thermocellum has 0 NA values
# Column Ruminococcaceae bacterium D16 has 0 NA values
# Column Ruminococcus albus has 0 NA values
# Column Ruminococcus callidus has 0 NA values
# Column Ruminococcus champanellensis has 0 NA values
# Column Ruminococcus flavefaciens has 0 NA values
# Column Ruminococcus sp. DSM 100440 has 0 NA values
# Column Sporobacter termitidis has 0 NA values
# Column Streptococcus infantarius has 0 NA values
# Column Streptococcus mitis has 0 NA values
# Column Streptococcus oralis has 0 NA values
# Column Sutterella parvirubra has 0 NA values
# Column Thermobaculum terrenum has 0 NA values
# Column Victivallis sp. MC_44 has 0 NA values
# Column Bacteroides pectinophilus has 0 NA values
# Column Clostridium aldenense has 0 NA values
# Column Clostridium asparagiforme has 0 NA values
# Column Clostridium bolteae has 0 NA values
# Column Clostridium celerecrescens has 0 NA values
# Column Clostridium cellobioparum has 0 NA values
# Column Clostridium clariflavum has 0 NA values
# Column Clostridium colinum has 0 NA values
# Column Clostridium indolis has 0 NA values
# Column Clostridium leptum has 0 NA values
# Column Clostridium methylpentosum has 0 NA values
# Column Clostridium neopropionicum has 0 NA values
# Column Clostridium propionicum has 0 NA values
# Column Clostridium saccharogumia has 0 NA values
# Column Clostridium saccharolyticum has 0 NA values
# Column Clostridium sphenoides has 0 NA values
# Column Clostridium spiroforme has 0 NA values
# Column Clostridium stercorarium has 0 NA values
# Column Clostridium symbiosum has 0 NA values
# Column Clostridium thermosuccinogenes has 0 NA values
# Column Clostridium xylanolyticum has 0 NA values
# Column Eubacterium brachy has 0 NA values
# Column Eubacterium dolichum has 0 NA values
# Column Eubacterium sulci has 0 NA values
# Column Ruminococcus gnavus has 0 NA values

# %%
# Drop duplicate rows
duplicates = train_dframe.duplicated().sum()
print(f"Duplicates = {duplicates}")
train_df_nodup = train_dframe.drop_duplicates()
# Out:
# Duplicates = 0

# %%
# Make plots for initial exploration
# Of course, this separation is just for the plots as bmi is expected to difer across sexes
# The entire dataframe will be used for training
males = train_df_nodup[train_df_nodup['Sex']=='Male']
females = train_df_nodup[train_df_nodup['Sex']=='Female']
males.hist(figsize = (42,42))
females.hist(figsize = (42,42), color='red')
plt.show()
